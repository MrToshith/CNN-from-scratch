# %% [markdown]
# # Using Tensorflow

# %% [markdown]
# ### Step-1: Import libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models # type: ignore
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step-2: Load and preprocess data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

x_train = x_train[..., np.newaxis]  
x_test = x_test[..., np.newaxis]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# ### Step-3: Build CNN model

# %%
model = models.Sequential([
    layers.Conv2D(
        filters=8,
        kernel_size=(3,3),
        activation='relu',
        input_shape=(28,28,1)
    ),
    layers.MaxPooling2D(pool_size=(2,2)),
    layers.Flatten(),
    layers.Dense(10, activation='softmax')
])

# %% [markdown]
# ### Step-4: Compile model

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### Step-5: Training

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.1
)
# Out:
# Epoch 1/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8989 - loss: 0.3802 - val_accuracy: 0.9620 - val_loss: 0.1386
# Epoch 2/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9604 - loss: 0.1390 - val_accuracy: 0.9753 - val_loss: 0.0951
# Epoch 3/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9701 - loss: 0.1021 - val_accuracy: 0.9805 - val_loss: 0.0772
# Epoch 4/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9755 - loss: 0.0849 - val_accuracy: 0.9805 - val_loss: 0.0728
# Epoch 5/5
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9777 - loss: 0.0754 - val_accuracy: 0.9827 - val_loss: 0.0668

# %% [markdown]
# ### Test and save model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)

model.save("../models/cnn_model.keras", save_format="keras")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9766 - loss: 0.0751
# WARNING:absl:The `save_format` argument is deprecated in Keras 3. We recommend removing this argument as it can be inferred from the file path. Received: save_format=keras
# Test accuracy: 0.9765999913215637
